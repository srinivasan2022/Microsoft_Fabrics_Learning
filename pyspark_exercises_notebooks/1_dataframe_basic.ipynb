# %% [markdown]
# ### Create the simple data frame

# %%
data = [("United States","US",40,44,42,126),
("China","CHN",40,27,24,91),
("Japan","JPN",20,12,13,45),
("Australia","AUS",18,19,16,53),
("France","FRA",16,26,22,64),
("Netherlands","NED",15,7,12,34),
("Great Britain","GBG",14,22,29,65),
("South Korea","KOR",13,9,10,32),
("Italy","ITA",12,13,15,40),
("Germany","GER",12,13,8,33),
("New Zealand","NZ",10,7,3,20)
]

columns = ["Country","Code","Gold","Sliver","Bronze","Total"]

df = spark.createDataFrame(data=data , schema=columns)
df.printSchema()
df.show(truncate=False)
# Out:
# StatementMeta(, 03e1d6f7-acb1-4972-9f50-3ab6a9514df4, 3, Finished, Available, Finished)
# root
#  |-- Country: string (nullable = true)
#  |-- Code: string (nullable = true)
#  |-- Gold: long (nullable = true)
#  |-- Sliver: long (nullable = true)
#  |-- Bronze: long (nullable = true)
#  |-- Total: long (nullable = true)
#
# +-------------+----+----+------+------+-----+
# |Country      |Code|Gold|Sliver|Bronze|Total|
# +-------------+----+----+------+------+-----+
# |United States|US  |40  |44    |42    |126  |
# |China        |CHN |40  |27    |24    |91   |
# |Japan        |JPN |20  |12    |13    |45   |
# |Australia    |AUS |18  |19    |16    |53   |
# |France       |FRA |16  |26    |22    |64   |
# |Netherlands  |NED |15  |7     |12    |34   |
# |Great Britain|GBG |14  |22    |29    |65   |
# |South Korea  |KOR |13  |9     |10    |32   |
# |Italy        |ITA |12  |13    |15    |40   |
# |Germany      |GER |12  |13    |8     |33   |
# |New Zealand  |NZ  |10  |7     |3     |20   |
# +-------------+----+----+------+------+-----+

# %% [markdown]
# ### Display the type of dataframe

# %%
spark.createDataFrame(data=data , schema=columns).printSchema()
# Out:
# StatementMeta(, 6e98b4a0-5194-4856-96aa-227747b2a204, 26, Finished, Available, Finished)
# root
#  |-- Country: string (nullable = true)
#  |-- Code: string (nullable = true)
#  |-- Gold: long (nullable = true)
#  |-- Sliver: long (nullable = true)
#  |-- Bronze: long (nullable = true)
#  |-- Total: long (nullable = true)

# %% [markdown]
# ### Display the dataframe

# %%
spark.createDataFrame(data=data , schema=columns).show()
# Out:
# StatementMeta(, 03e1d6f7-acb1-4972-9f50-3ab6a9514df4, 4, Finished, Available, Finished)
# +-------------+----+----+------+------+-----+
# |      Country|Code|Gold|Sliver|Bronze|Total|
# +-------------+----+----+------+------+-----+
# |United States|  US|  40|    44|    42|  126|
# |        China| CHN|  40|    27|    24|   91|
# |        Japan| JPN|  20|    12|    13|   45|
# |    Australia| AUS|  18|    19|    16|   53|
# |       France| FRA|  16|    26|    22|   64|
# |  Netherlands| NED|  15|     7|    12|   34|
# |Great Britain| GBG|  14|    22|    29|   65|
# |  South Korea| KOR|  13|     9|    10|   32|
# |        Italy| ITA|  12|    13|    15|   40|
# |      Germany| GER|  12|    13|     8|   33|
# |  New Zealand|  NZ|  10|     7|     3|   20|
# +-------------+----+----+------+------+-----+

# %% [markdown]
# ### Display the dataframe in table format

# %%
display(df)
# Out:
# StatementMeta(, 6e98b4a0-5194-4856-96aa-227747b2a204, 28, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, e4ee07f1-73c5-440e-a2c9-5123bf645a27)

# %% [markdown]
# ### Display the datatype

# %%
type (df)
# Out:
# StatementMeta(, 6e98b4a0-5194-4856-96aa-227747b2a204, 19, Finished, Available, Finished)
# pyspark.sql.dataframe.DataFrame

# %%
type(df.Country)
# Out:
# StatementMeta(, 6e98b4a0-5194-4856-96aa-227747b2a204, 21, Finished, Available, Finished)
# pyspark.sql.column.Column

# %%
type(df.Total)
# Out:
# StatementMeta(, 6e98b4a0-5194-4856-96aa-227747b2a204, 22, Finished, Available, Finished)
# pyspark.sql.column.Column

# %% [markdown]
# ### Creates the dataframe using structType (python)

# %% [markdown]
# ##

# %%
from pyspark.sql.types import StructType,StructField, StringType, IntegerType

data = [("United States","US",40,44,42,126),
("China","CHN",40,27,24,91),
("Japan","JPN",20,12,13,45),
("Australia","AUS",18,19,16,53),
("France","FRA",16,26,22,64),
("Netherlands","NED",15,7,12,34),
("Great Britain","GBG",14,22,29,65),
("South Korea","KOR",13,9,10,32),
("Italy","ITA",12,13,15,40),
("Germany","GER",12,13,8,33),
("New Zealand","NZ",10,7,3,20)
]

columns = StructType([
    StructField("Country" , StringType() , True) ,
    StructField("Code" , StringType() , True) ,
    StructField("Gold" , IntegerType() , True) ,
    StructField("Silver" , IntegerType() , True) ,
    StructField("Bronze" , IntegerType() , True) ,
    StructField("Total" , IntegerType() , True)
])

dfpy = spark.createDataFrame(data=data , schema=columns)
dfpy.printSchema()
dfpy.show(truncate=False)
# Out:
# StatementMeta(, 6e98b4a0-5194-4856-96aa-227747b2a204, 36, Finished, Available, Finished)
# root
#  |-- Country: string (nullable = true)
#  |-- Code: string (nullable = true)
#  |-- Gold: integer (nullable = true)
#  |-- Silver: integer (nullable = true)
#  |-- Bronze: integer (nullable = true)
#  |-- Total: integer (nullable = true)
#
# +-------------+----+----+------+------+-----+
# |Country      |Code|Gold|Silver|Bronze|Total|
# +-------------+----+----+------+------+-----+
# |United States|US  |40  |44    |42    |126  |
# |China        |CHN |40  |27    |24    |91   |
# |Japan        |JPN |20  |12    |13    |45   |
# |Australia    |AUS |18  |19    |16    |53   |
# |France       |FRA |16  |26    |22    |64   |
# |Netherlands  |NED |15  |7     |12    |34   |
# |Great Britain|GBG |14  |22    |29    |65   |
# |South Korea  |KOR |13  |9     |10    |32   |
# |Italy        |ITA |12  |13    |15    |40   |
# |Germany      |GER |12  |13    |8     |33   |
# |New Zealand  |NZ  |10  |7     |3     |20   |
# +-------------+----+----+------+------+-----+

# %% [markdown]
# ### Creates the dataframe using Data Definition Language (ddl - Sql)

# %%
columns_ddl = "Country STRING, Code STRING, Gold INT,Sliver INT,Bronze INT, Total INT"
ddl = spark.createDataFrame(data=data,schema=columns_ddl)
ddl.printSchema()
ddl.show(truncate=False)
display(ddl)
# Out:
# StatementMeta(, 6e98b4a0-5194-4856-96aa-227747b2a204, 33, Finished, Available, Finished)
# root
#  |-- Country: string (nullable = true)
#  |-- Code: string (nullable = true)
#  |-- Gold: integer (nullable = true)
#  |-- Sliver: integer (nullable = true)
#  |-- Bronze: integer (nullable = true)
#  |-- Total: integer (nullable = true)
#
# +-------------+----+----+------+------+-----+
# |Country      |Code|Gold|Sliver|Bronze|Total|
# +-------------+----+----+------+------+-----+
# |United States|US  |40  |44    |42    |126  |
# |China        |CHN |40  |27    |24    |91   |
# |Japan        |JPN |20  |12    |13    |45   |
# |Australia    |AUS |18  |19    |16    |53   |
# |France       |FRA |16  |26    |22    |64   |
# |Netherlands  |NED |15  |7     |12    |34   |
# |Great Britain|GBG |14  |22    |29    |65   |
# |South Korea  |KOR |13  |9     |10    |32   |
# |Italy        |ITA |12  |13    |15    |40   |
# |Germany      |GER |12  |13    |8     |33   |
# |New Zealand  |NZ  |10  |7     |3     |20   |
# +-------------+----+----+------+------+-----+
# SynapseWidget(Synapse.DataFrame, 8d2dc22a-69e9-4988-afbd-1a423f2ffd9d)

# %% [markdown]
# ### Display the first few rows of dataframe

# %%
df.show(2)
# Out:
# StatementMeta(, 03e1d6f7-acb1-4972-9f50-3ab6a9514df4, 5, Finished, Available, Finished)
# +-------------+----+----+------+------+-----+
# |      Country|Code|Gold|Sliver|Bronze|Total|
# +-------------+----+----+------+------+-----+
# |United States|  US|  40|    44|    42|  126|
# |        China| CHN|  40|    27|    24|   91|
# +-------------+----+----+------+------+-----+
# only showing top 2 rows

# %% [markdown]
# - display(df) --> display the dataframe in table format
# - display(df.head(2)) --> display the first two rows
# - display(df.tail(2)) --> display the last two rows

# %%
display(df.head(2))
# Out:
# StatementMeta(, 03e1d6f7-acb1-4972-9f50-3ab6a9514df4, 6, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, da164d25-95ad-484b-864d-0ff01060185b)

# %%
dff =df.tail(2)
display(dff)
# Out:
# StatementMeta(, 4490ae79-7883-480f-8c9e-c596b5fee4cf, 6, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, a65ab6e5-bc07-4b1c-bdd8-f604c4535b9c)
