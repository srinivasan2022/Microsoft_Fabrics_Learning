# %%
df = spark.read.format("csv").option("header","true").load("Files/data/Supermart Grocery Sales - Retail Analytics Dataset.csv")
# Out:
# StatementMeta(, 333cb8cf-7a7b-4749-93d5-ef83788e5357, 3, Finished, Available, Finished)

# %%
df.createOrReplaceTempView("orders")
# Out:
# StatementMeta(, 333cb8cf-7a7b-4749-93d5-ef83788e5357, 4, Finished, Available, Finished)

# %%
# %%sql
# SELECT * FROM orders
# Out:
# StatementMeta(, 333cb8cf-7a7b-4749-93d5-ef83788e5357, 5, Finished, Available, Finished)
# <Spark SQL result set with 1000 rows and 11 fields>

# %% [markdown]
# **1.Write a query to find the total sales in each region**

# %%
# %%sql
# SELECT Region , count(sales) AS Total_sales
# from orders
# GROUP BY Region
# Out:
# StatementMeta(, 333cb8cf-7a7b-4749-93d5-ef83788e5357, 15, Finished, Available, Finished)
# <Spark SQL result set with 5 rows and 2 fields>

# %% [markdown]
# **2.Count how many orders were placed by each customer.**

# %%
# %%sql
# SELECT Customer_Name , count(Order_Date) AS Total_Orders
# from orders
# GROUP BY Customer_Name
# Out:
# StatementMeta(, 333cb8cf-7a7b-4749-93d5-ef83788e5357, 16, Finished, Available, Finished)
# <Spark SQL result set with 50 rows and 2 fields>

# %% [markdown]
# **3.Find all orders with a discount of more than 20% but less than 30%**

# %%
# %%sql
# SELECT * FROM orders
# WHERE Discount > 0.2 AND Discount < 0.3
# Out:
# StatementMeta(, 7512dd62-2961-478e-8fd5-c8c6194a256a, 25, Finished, Available, Finished)
# <Spark SQL result set with 1000 rows and 11 fields>

# %% [markdown]
# **4.List the top 3 orders by profit**

# %%
# %%sql
# SELECT * FROM orders
# ORDER BY Profit DESC
# LIMIT 3
# Out:
# StatementMeta(, 7512dd62-2961-478e-8fd5-c8c6194a256a, 31, Finished, Available, Finished)
# <Spark SQL result set with 3 rows and 11 fields>

# %% [markdown]
# **5.Replace the category 'Snacks' with 'Quick Bites' in the result**

# %%
# %%sql
# SELECT Order_ID,
#        REPLACE(Category, 'Snacks', 'Quick Bites') AS Category
# FROM orders;
# Out:
# StatementMeta(, 333cb8cf-7a7b-4749-93d5-ef83788e5357, 14, Finished, Available, Finished)
# <Spark SQL result set with 1000 rows and 2 fields>
